# %% [markdown]
# # Summary of results for solving elliptic differential equation by PINNS
#
# The equation we solve read $ \frac{\partial^{2}}{ \partial^{2} x} u(x,y)
#     +\frac{\partial^{2}}{ \partial^{2} y} u(x,y) =0.$

# %%
import time
import torch

from scipy.stats import qmc
import numpy as np

from  src_nna.pinns.nn_pinns import MLP_PINN
from src_nna.pinns.elliptic_pde import elliptic_pde_2d
from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.pyplot as plt

# %% [markdown]
# For the boundary condition being a constant function $c=3$, we experiment with the complexity of the model.

# %%
plotting = True
n_bc = 4
n_data_per_bc = 2000
Lx=1.0
Ly=1.0 

Nc = 1000 
n = 700

num_hidden=12
num_layers=8

lear_rate=  5e-3
num_iteration = 5000000 

function_bound = elliptic_pde_2d.cnst

for num_layers in [4, 6, 8, 10]:
    for j in range(4):
        num_hidden = np.power(2, 3+j)
        print("# hidden layers:", num_layers)
        print("#units in hidden layers:", num_hidden)

        elliptic_pde_2d.run_traning(n_bc, Lx, Ly, Nc, n, num_hidden, num_layers,
                        lear_rate, num_iteration, function_bound,
                          n_data_per_bc, plotting = False, verbose=False)
# Out:
# # hidden layers: 4
# #units in hidden layers: 8
# start training:
#   2%|▏         | 1228/50001 [00:12<07:57, 102.05it/s]
# early stopping
# computation time: 12.3294
# # hidden layers: 4
# #units in hidden layers: 16
# start training:
#   6%|▌         | 2754/50001 [00:30<08:44, 90.04it/s]
# early stopping
# computation time: 30.5907
# # hidden layers: 4
# #units in hidden layers: 32
# start training:
#   3%|▎         | 1484/50001 [00:20<11:25, 70.80it/s]
# early stopping
# computation time: 20.9653
# # hidden layers: 4
# #units in hidden layers: 64
# start training:
#   2%|▏         | 957/50001 [00:22<19:37, 41.65it/s]
# early stopping
# computation time: 22.9787
# # hidden layers: 6
# #units in hidden layers: 8
# start training:
#   4%|▍         | 2110/50001 [01:08<26:02, 30.65it/s]
# early stopping
# computation time: 68.8382
# # hidden layers: 6
# #units in hidden layers: 16
# start training:
# 100%|██████████| 50001/50001 [25:07<00:00, 33.18it/s]
# computation time: 1507.1831
# ...

# %% [markdown]
# Here,we explore the PINN simulations for approximating functions with different boundary functions. The complexity of model is fixed here.

# %%
plotting = True
n_bc = 4
n_data_per_bc = 2000
Lx=1.0
Ly=1.0 

Nc = 1000 
n = 700

num_hidden=16
num_layers=6

lear_rate=  5e-3
num_iteration = 5000000 

function_bound = elliptic_pde_2d.cnst

for function_bound in [elliptic_pde_2d.x_lin, elliptic_pde_2d.x_pow2, elliptic_pde_2d.cos, elliptic_pde_2d.sin,  elliptic_pde_2d.x_sqrt]:
        print("function on the boundary:", function_bound)

        elliptic_pde_2d.run_traning(n_bc, Lx, Ly, Nc, n, num_hidden, num_layers,
                        lear_rate, num_iteration, function_bound,
                          n_data_per_bc, plotting = False, verbose=False)
# Out:
# function on the boundary: <function x_lin at 0x16d458cc0>
# start training:
#   0%|          | 941/5000001 [00:12<18:46:57, 73.93it/s]
# early stopping
# computation time: 12.7340
# function on the boundary: <function x_pow2 at 0x16d458c20>
# start training:
#   0%|          | 367/5000001 [00:06<22:58:11, 60.46it/s]
# early stopping
# computation time: 6.0746
# function on the boundary: <function cos at 0x16bce49a0>
# start training:
#   0%|          | 1416/5000001 [00:21<20:55:04, 66.38it/s]
# early stopping
# computation time: 21.3351
# function on the boundary: <function sin at 0x16d458ae0>
# start training:
#   0%|          | 1072/5000001 [00:15<19:58:50, 69.50it/s]
# early stopping
# computation time: 15.4284
# function on the boundary: <function x_sqrt at 0x16d458b80>
# start training:
#   0%|          | 3485/5000001 [01:29<35:42:47, 38.86it/s]
# early stopping
# computation time: 89.6790
