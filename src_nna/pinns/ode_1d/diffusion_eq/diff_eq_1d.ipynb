# %% [markdown]
# # Solving 1d ODE
#
# This Jupyter notebook contains the implementation of a 1D differential equations solver. The solver uses numerical methods to approximate solutions to ordinary differential equations (ODEs).
#
# $u + \epsilon  u_{xx} =1$

# %%
import torch
import numpy as np

from src_nna.pinns.ode_1d.diffusion_eq import diff_eq_1d

from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# Here we experiment the role of model complexity in approximating the function.

# %%
num_input=1
num_output=1
num_hidden=32
num_layers=3

lear_rate= 1e-2

epsilon =0.1
num_iteration = 7500

plotting= False

for num_layers in [4, 6, 8, 10]:
    for j in range(3):
        num_hidden = np.power(2, 3+j)
        print("# hidden layers:", num_layers)
        print("#units in hidden layers:", num_hidden)

        diff_eq_1d.run_training(epsilon, num_hidden, num_layers,
                    lear_rate,num_iteration, plotting)
# Out:
# # hidden layers: 4
# #units in hidden layers: 8
#  84%|████████▍ | 6298/7501 [00:10<00:01, 609.36it/s]
# early stopping
# computation time: 10.8267
# # hidden layers: 4
# #units in hidden layers: 16
#  97%|█████████▋| 7242/7501 [00:12<00:00, 579.70it/s]
# early stopping
# computation time: 12.4963
# # hidden layers: 4
# #units in hidden layers: 32
#  67%|██████▋   | 5026/7501 [00:11<00:05, 435.93it/s]
# early stopping
# computation time: 11.5334
# # hidden layers: 6
# #units in hidden layers: 8
#   9%|▊         | 638/7501 [00:01<00:13, 508.88it/s]
# early stopping
# computation time: 1.2600
# # hidden layers: 6
# #units in hidden layers: 16
#  65%|██████▌   | 4908/7501 [00:11<00:06, 418.03it/s]
# early stopping
# computation time: 11.7461
# # hidden layers: 6
# #units in hidden layers: 32
#  37%|███▋      | 2788/7501 [00:08<00:14, 328.74it/s]
# early stopping
# computation time: 8.4853
# # hidden layers: 8
# #units in hidden layers: 8
# ...

# %% [markdown]
# Examining the performance of the code as we vary $\varepsilon$

# %%
num_input=1
num_output=1
num_hidden=32
num_layers=4

lear_rate= 1e-2

epsilon =0.1
num_iteration = 50000

plotting = False


for epsilon in [ 0.05, 0.1, 0.2]:
    for lear_rate in [1e-2, 5e-3, 1e-3, 1e-4]:
        print("epsilon:", epsilon, "learning rate:", lear_rate)

        diff_eq_1d.run_training(epsilon, num_hidden, num_layers,
                        lear_rate,num_iteration, plotting)
# Out:
# epsilon: 0.05 learning rate: 0.01
#   3%|▎         | 1557/50001 [00:03<01:43, 466.87it/s]
# early stopping
# computation time: 3.3409
# epsilon: 0.05 learning rate: 0.005
#   3%|▎         | 1524/50001 [00:03<01:43, 470.10it/s]
# early stopping
# computation time: 3.2463
# epsilon: 0.05 learning rate: 0.001
#  28%|██▊       | 14128/50001 [00:30<01:17, 465.19it/s]
# Converged at iteration 14128 final error: tensor(9.9975e-06, grad_fn=<MeanBackward0>)
# computation time: 30.3747
# epsilon: 0.05 learning rate: 0.0001
#   9%|▊         | 4333/50001 [00:10<01:45, 431.10it/s]
# early stopping
# computation time: 10.0555
# epsilon: 0.1 learning rate: 0.01
#   4%|▎         | 1846/50001 [00:03<01:38, 490.59it/s]
# early stopping
# computation time: 3.7668
# epsilon: 0.1 learning rate: 0.005
#  10%|█         | 5031/50001 [00:10<01:34, 477.65it/s]
# early stopping
# computation time: 10.5372
# epsilon: 0.1 learning rate: 0.001
#  15%|█▍        | 7346/50001 [00:16<01:33, 454.65it/s]
# ...
