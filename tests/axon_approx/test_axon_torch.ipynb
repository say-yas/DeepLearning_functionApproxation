# %%
import numpy as np
from src_nna.axon_approx.src.axon_approximation import axon_algorithm
from src_nna.axon_approx.src.axon_model_torch import train_random_model_torch

import matplotlib.pyplot as plt
plt.rc('font', size=14)
plt.rcParams.update({"text.usetex": True})

# %%
def plot_errors(data, data_rnd, title):
    plt.plot(np.arange(1,101), data, label='axon algorithm')
    plt.plot(np.arange(1,len(data_rnd)+1), data_rnd, label='random initialization')
    plt.yscale('log')
    plt.ylabel('error')
    plt.xlabel('K')
    plt.title(title)
    plt.legend()
    plt.xticks(np.arange(0,102, 10))

# %%
def plot_basis(data, name):
    plt.figure(figsize=(10,6))
    for i in range(6):
        plt.subplot(2,3,i+1)
        plt.ylabel(r'$\phi_{}(x)$'.format(i))
        plt.xlabel(r'$x$')
        if i == 0:
            plt.plot(np.linspace(0,1,1000), np.ones(1000)*data[0,0]) 
            # otherwise the constant function is has strange value
        else:
            plt.plot(np.linspace(0,1,1000), data[:,i])
    plt.tight_layout()

# %% [markdown]
# ## 1D case

# %% [markdown]
# Here we present several examples of applying our algorithm and compare its performance with classical training.
# For the fast computation, we train the network only a few epochs and only for a few number of basis functions

# %%
xs = np.linspace(0, 1, 1000)[:,None]

# %% [markdown]
# 1. First we consider function $f(x) = x^2$

# %%
# our method of network training

ys = (xs**2).flatten()
bs_x2, bs_coefs, r, coefs, norms, errs_x2 = axon_algorithm(xs, ys, 100)

# %%
# obtained basis functions
plot_basis(bs_x2, r'$x^2$')

# %% [markdown]
# We can compare accuracy of our algorithm with convenitional training with random initialization. We select minimal error over 20 runs. In the paper the number of epochs is 1000, here it is 10 only for the quick demonstration

# %%
# classical training with random initialization
errs_rnd = []

for k in range(1,10):
    err_k = train_random_model_torch(xs, lambda x: x**2, K=k, num_epochs=10, num_iters=1000)
    err_k = [err for err in err_k if not np.isnan(err)] # to avoid nans when min is searched
    errs_rnd.append(min(err_k))

print(errs_rnd)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 308.51it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 202.81it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 143.88it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 109.96it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 90.30it/s]
# 100%|██████████| 1000/1000 [00:13<00:00, 75.05it/s]
# 100%|██████████| 1000/1000 [00:16<00:00, 61.77it/s]
# 100%|██████████| 1000/1000 [00:18<00:00, 54.76it/s]
# 100%|██████████| 1000/1000 [00:21<00:00, 46.10it/s]
# [0.06300166249275208, 0.052014488726854324, 0.08550912141799927, 0.06779764592647552, 0.07943199574947357, 0.051755405962467194, 0.07759939134120941, 0.08916815370321274, 0.1471991091966629]

# %%
plot_errors(errs_x2, errs_rnd, r'$x^2$')

# %% [markdown]
# 2. Another example is $f(x) = \sqrt{x}$

# %%
ys = np.sqrt(xs).flatten()
bs_sqrt, bs_coefs, r, coefs, norms, errs_sqrt = axon_algorithm(xs, ys, 100)

# %%
# obtained basis functions
plot_basis(bs_sqrt, r'$x^2$')

# %%
# classical training with random initialization
errs_rnd = []

for k in range(1,10):
    err_k = train_random_model_torch(xs, lambda x: np.sqrt(x), K=k, num_epochs=10)
    err_k = [err for err in err_k if not np.isnan(err)] # to avoid nans when min is searched
    errs_rnd.append(min(err_k))
# Out:
# 100%|██████████| 1000/1000 [00:02<00:00, 364.62it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 207.36it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 132.26it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 108.34it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 83.91it/s]
# 100%|██████████| 1000/1000 [00:13<00:00, 73.62it/s]
# 100%|██████████| 1000/1000 [00:16<00:00, 61.39it/s]
# 100%|██████████| 1000/1000 [00:19<00:00, 51.82it/s]
# 100%|██████████| 1000/1000 [00:21<00:00, 47.39it/s]

# %%
plot_errors(errs_sqrt, errs_rnd, r'$\sqrt{x}$')
